# %%
import os
import pandas as pd
# set option for pandas
#pd.set_option('max_rows',None)
#pd.set_option('max_columns',None)

# reset option
#pd.reset_option("all")

# %%
os.getcwd()
# Out:
# 'c:\\Users\\Student\\Documents\\New folder'

# %%
df = pd.read_csv("pokemon.csv")

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df_xl = pd.read_excel("pokemon.xlsx")

# %%
df_xl
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df_txt = pd.read_csv("pokemon.txt", delimiter="\t")

# %%
df_txt
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.tail(9)
# Out:
#        #                 Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 791  715              Noivern   Flying  Dragon   85      70       80       97
# 792  716              Xerneas    Fairy     NaN  126     131       95      131
# 793  717              Yveltal     Dark  Flying  126     131       95      131
# 794  718     Zygarde50% Forme   Dragon  Ground  108     100      121       81
# 795  719              Diancie     Rock   Fairy   50     100      150      100
# 796  719  DiancieMega Diancie     Rock   Fairy   50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic   Ghost   80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic    Dark   80     160       60      170
# 799  721            Volcanion     Fire   Water   80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 791       80    123           6      False
# 792       98     99           6       True
# 793       98     99           6       True
# ...

# %%
# loc takes data from lable marked function for loction
df.loc[1,"Name"]
# Out:
# 'Ivysaur'

# %%
#fetch data with index
#iloc[rows,columns]
df.iloc[1,1]
# Out:
# 'Ivysaur'

# %%
df.iloc[1:6,1:9]
# Out:
#                     Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def
# 1                Ivysaur  Grass  Poison  60      62       63       80       80
# 2               Venusaur  Grass  Poison  80      82       83      100      100
# 3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122      120
# 4             Charmander   Fire     NaN  39      52       43       60       50
# 5             Charmeleon   Fire     NaN  58      64       58       80       65

# %%
df[['Name','HP','Attack','Defense']]
df1 = df[['Name','HP']]

# %%
df1.iloc[55:59,0:2]
# Out:
#        Name  HP
# 55  Diglett  10
# 56  Dugtrio  35
# 57   Meowth  40
# 58  Persian  65

# %%
df1.loc[55:61,{'Name','HP'}]
# Out:
#        Name  HP
# 55  Diglett  10
# 56  Dugtrio  35
# 57   Meowth  40
# 58  Persian  65
# 59  Psyduck  50
# 60  Golduck  80
# 61   Mankey  40

# %%
df.loc[55:61,{'Name','Speed'}]
# Out:
#        Name  Speed
# 55  Diglett     95
# 56  Dugtrio    120
# 57   Meowth     90
# 58  Persian    115
# 59  Psyduck     55
# 60  Golduck     85
# 61   Mankey     70

# %%
# exclude index column in data
df2 = pd.read_csv("pokemon.csv", index_col=0)
df2
# Out:
#                       Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# #
# 1                Bulbasaur    Grass  Poison  45      49       49       65
# 2                  Ivysaur    Grass  Poison  60      62       63       80
# 3                 Venusaur    Grass  Poison  80      82       83      100
# 3    VenusaurMega Venusaur    Grass  Poison  80     100      123      122
# 4               Charmander     Fire     NaN  39      52       43       60
# ..                     ...      ...     ...  ..     ...      ...      ...
# 719                Diancie     Rock   Fairy  50     100      150      100
# 719    DiancieMega Diancie     Rock   Fairy  50     160      110      160
# 720    HoopaHoopa Confined  Psychic   Ghost  80     110       60      150
# 720     HoopaHoopa Unbound  Psychic    Dark  80     160       60      170
# 721              Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# #
# ...

# %%
df2 = df2.set_index('Speed')
df2
# Out:
#                         Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# Speed
# 45                 Bulbasaur    Grass  Poison  45      49       49       65
# 60                   Ivysaur    Grass  Poison  60      62       63       80
# 80                  Venusaur    Grass  Poison  80      82       83      100
# 80     VenusaurMega Venusaur    Grass  Poison  80     100      123      122
# 65                Charmander     Fire     NaN  39      52       43       60
# ...                      ...      ...     ...  ..     ...      ...      ...
# 50                   Diancie     Rock   Fairy  50     100      150      100
# 110      DiancieMega Diancie     Rock   Fairy  50     160      110      160
# 70       HoopaHoopa Confined  Psychic   Ghost  80     110       60      150
# 80        HoopaHoopa Unbound  Psychic    Dark  80     160       60      170
# 70                 Volcanion     Fire   Water  80     110      120      130
#
#        Sp. Def  Generation  Legendary
# Speed
# ...

# %%
df2.head(4)
# Out:
#                         Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# Speed
# 45                 Bulbasaur  Grass  Poison  45      49       49       65
# 60                   Ivysaur  Grass  Poison  60      62       63       80
# 80                  Venusaur  Grass  Poison  80      82       83      100
# 80     VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#        Sp. Def  Generation  Legendary
# Speed
# 45          65           1      False
# 60          80           1      False
# 80         100           1      False
# 80         120           1      False

# %%
df2.loc[{45,60,80,80}]
# Out:
#                         Name    Type 1   Type 2   HP  Attack  Defense  \
# Speed
# 80                  Venusaur     Grass   Poison   80      82       83
# 80     VenusaurMega Venusaur     Grass   Poison   80     100      123
# 80                Charmeleon      Fire      NaN   58      64       58
# 80                     Arbok    Poison      NaN   60      85       69
# 80                    Gastly     Ghost   Poison   30      35       30
# ...                      ...       ...      ...  ...     ...      ...
# 45                Conkeldurr  Fighting      NaN  105     140       95
# 45                     Throh  Fighting      NaN  120     100       85
# 45                   Crustle       Bug     Rock   70      95      125
# 45                   Gothita   Psychic      NaN   45      30       50
# 45                     Inkay      Dark  Psychic   53      54       53
#
#        Sp. Atk  Sp. Def  Generation  Legendary
# Speed
# 80         100      100           1      False
# ...

# %%
df.loc[(df['Type 1'] == 'Grass') & (df['HP'] > 40)]
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49       49
# 1      2                Ivysaur  Grass    Poison   60      62       63
# 2      3               Venusaur  Grass    Poison   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100      123
# 48    43                 Oddish  Grass    Poison   45      50       55
# ..   ...                    ...    ...       ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN   56      61       65
# 719  651              Quilladin  Grass       NaN   61      78       95
# 720  652             Chesnaught  Grass  Fighting   88     107      122
# 740  672                 Skiddo  Grass       NaN   66      65       48
# 741  673                 Gogoat  Grass       NaN  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.loc[(df['Type 1'] == 'Grass') | (df['Type 1']  == 'Fire')]
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 4      4             Charmander   Fire     NaN   39      52       43       60
# ..   ...                    ...    ...     ...  ...     ...      ...      ...
# 735  667                 Litleo   Fire  Normal   62      50       58       73
# 736  668                 Pyroar   Fire  Normal   86      68       72      109
# 740  672                 Skiddo  Grass     NaN   66      65       48       62
# 741  673                 Gogoat  Grass     NaN  123     100       62       97
# 799  721              Volcanion   Fire   Water   80     110      120      130
#
# ...

# %%
#list all pokemons of grass or fire with hp > 40
new = df.loc[(df['Type 1'] == 'Grass') | (df['Type 1']  == 'Fire') & (df['HP'] > 40),{'Name','Speed'}]
new
# Out:
#                       Name  Speed
# 0                Bulbasaur     45
# 1                  Ivysaur     60
# 2                 Venusaur     80
# 3    VenusaurMega Venusaur     80
# 5               Charmeleon     80
# ..                     ...    ...
# 735                 Litleo     72
# 736                 Pyroar    106
# 740                 Skiddo     52
# 741                 Gogoat     68
# 799              Volcanion     70
#
# [117 rows x 2 columns]

# %%
#create new csv file 
new.to_csv("newpokemon.csv")
# to save as text
#new.to_csv("newpokemon.txt",sep="\t")

# %%
#new.to_csv("newpokemon.txt",sep="a")
df007 = pd.read_csv("newpokemon.txt", delimiter="a")
df007
# Out:
#      Unnamed: 0                   Name  Speed
# 0             0              Bulbasaur     45
# 1             1                Ivysaur     60
# 2             2               Venusaur     80
# 3             3  VenusaurMega Venusaur     80
# 4             5             Charmeleon     80
# ..          ...                    ...    ...
# 112         735                 Litleo     72
# 113         736                 Pyroar    106
# 114         740                 Skiddo     52
# 115         741                 Gogoat     68
# 116         799              Volcanion     70
#
# [117 rows x 3 columns]
